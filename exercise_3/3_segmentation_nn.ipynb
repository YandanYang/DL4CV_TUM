# %% [markdown]
# Semantic Segmentation
# ============
#
# In this exercise you are going to work on a computer vision task called semantic segmentation. In comparison to image classification the goal is not to classify an entire image but each of its pixels separately. This implies that the  output of the network is not a single scalar but a segmentation with the same shape as the input image. Think about why you should rather use convolutional than fully-connected layers for this task!
#
# Since we already introduced the basics of PyTorch and how to train a NN we leave the model design and architecture as well as the training up to you. We only provide you with the train, validation and test dataset and recommend you to look for inspirational, existing PyTorch implementations. Due to the fairly small size of the segmentation dataset you should not train a model from scratch but consider to (at least partially) finetune weights of an already exsisting model.
#
# The infamous  [Fully Convolutional Networks for Semantic Segmentation](https://people.eecs.berkeley.edu/~jonlong/long_shelhamer_fcn.pdf) paper might help you with finding a suitable segmentation model and architecture.
#
# <img src="https://camo.githubusercontent.com/d10b897e15344334e449104a824aff6c29125dc2/687474703a2f2f63616c76696e2e696e662e65642e61632e756b2f77702d636f6e74656e742f75706c6f6164732f646174612f636f636f7374756666646174617365742f636f636f73747566662d6578616d706c65732e706e67">

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.autograd import Variable
import torchvision

from dl4cv.classifiers.segmentation_nn import SegmentationNN
from dl4cv.data_utils import SegmentationData, label_img_to_rgb, OverfitSampler

#torch.set_default_tensor_type('torch.FloatTensor')

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# MSRC-v2 Segmentation Dataset
# ================
#
# Make yourself familiar with the segmentation dataset and how we implemented the `SegmentationData` class in `dl4cv/data_utils.py`. Furthermore have a look at the labels described in `data/segmentation_data/info.html`. Especially note the label `unlabeled`. Pixels with the label `unlabeled` should neither be considered in your loss nor in the accuracy of your segmentation.

# %%
train_data = SegmentationData(image_paths_file='datasets/segmentation_data/train.txt')
val_data = SegmentationData(image_paths_file='datasets/segmentation_data/val.txt')

# %%
print("Train size: %i" % len(train_data))
print("Validation size: %i" % len(val_data))
print("Img size: ", train_data[0][0].size())
print("Segmentation size: ", train_data[0][1].size())

num_example_imgs = 3
plt.figure(figsize=(10, 5 * num_example_imgs))
for i, (img, target) in enumerate(train_data[:num_example_imgs]):
    # img
    plt.subplot(num_example_imgs, 2, i * 2 + 1)
    plt.imshow(img.numpy().transpose(1,2,0))
    plt.axis('off')
    if i == 0:
        plt.title("Input image")
    
    # target
    plt.subplot(num_example_imgs, 2, i * 2 + 2)
    plt.imshow(label_img_to_rgb(target.numpy()))
    plt.axis('off')
    if i == 0:
        plt.title("Target image")
plt.show()
# Out:
# Train size: 276
# Validation size: 59
# Img size:  torch.Size([3, 240, 240])
# Segmentation size:  torch.Size([240, 240])

# %% [markdown]
# Design and Train your Network
# ==========
#
# Implement your network architecture in `dl4cv/classifiers/segmentation_nn.py` and adapt your `Solver` to process segmentation labels. To compensate for the dimension reduction of a typical convolution layer, you should probably include a `nn.Upsample` layer near the end of your network. Also remember to consider finetuning a model instead of training it from scratch.
#
# Up until now we only used the default loss function (`nn.CrossEntropyLoss`) of our `Solver` class. However, in order to ignore the `unlabeled` pixels for the computation of our loss, we have to usw a customized version of the loss for the initializtation of the `Solver` class. The `ignore_index` argument of the loss can be used to filter the `unlabeled` pixels and computes the loss only over remaining pixels.
#
# Step by step:
# 1. Initialize training and validation data loaders.
# 2. Design and initialize a convolutional neural network architecture that has input (N, C, H, W) and output (N, num_classes, H, W) and is based on an already pretrained network.
# 3. Initialize a solver with a loss function that considers the `unlabeled` pixels.
# 4. Adjust the logging of your solver to account for the `unlabeled` pixels.
# 5. Train a segmentation model.

# %%
#model=torchvision.models.vgg16_bn(pretrained=True)
#model=model.features
#model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b99da3fb93d7> in <module>()
#       1 #model=torchvision.models.vgg16_bn(pretrained=True)
#       2 #model=model.features
# ----> 3 model
#
# NameError: name 'model' is not defined

# %%
from dl4cv.classifiers.segmentation_nn import SegmentationNN
from dl4cv.solver import Solver
import torch.nn.functional as F
import torchvision

########################################################################
#                             YOUR CODE                                #
########################################################################
#overfit 
#torch.nn.CrossEntropyLoss(weight=None, size_average=True,ignore_index=-1)
#num_train =1000
#train_loader = torch.utils.data.DataLoader(train_data, batch_size=1, shuffle=False, num_workers=4,
#                                           sampler=OverfitSampler(num_train))
#val_loader = torch.utils.data.DataLoader(val_data, batch_size=5, shuffle=False, num_workers=4)

#overfit_model = SegmentationNN()
#overfit_solver = Solver(optim_args={"lr": 1e-3},\
#                        loss_func=torch.nn.CrossEntropyLoss(size_average=True,ignore_index=-1))
#overfit_solver.train(overfit_model, train_loader, val_loader, log_nth=5, num_epochs=100)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=5, shuffle=True, num_workers=4)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=5, shuffle=False, num_workers=4)


model = SegmentationNN()
solver = Solver(optim_args={"lr": 1e-4,"weight_decay": 1e-4},\
                loss_func=torch.nn.CrossEntropyLoss(size_average=True,ignore_index=-1))
solver.train(model, train_loader, val_loader, log_nth=10, num_epochs=100)
# Out:
# START TRAIN.
# [Iteration 10/5600] TRAIN loss: 3.183
# [Iteration 20/5600] TRAIN loss: 3.110
# [Iteration 30/5600] TRAIN loss: 3.060
# [Iteration 40/5600] TRAIN loss: 2.964
# [Iteration 50/5600] TRAIN loss: 2.906
# [Epoch 1/100] TRAIN acc/loss: 0.222/2.906
# [Epoch 1/100] VAL   acc/loss: 0.387/2.717
# [Iteration 66/5600] TRAIN loss: 2.717
# [Iteration 76/5600] TRAIN loss: 2.584
# [Iteration 86/5600] TRAIN loss: 2.626
# [Iteration 96/5600] TRAIN loss: 2.424
# [Iteration 106/5600] TRAIN loss: 2.385
# [Epoch 2/100] TRAIN acc/loss: 0.090/2.385
# [Epoch 2/100] VAL   acc/loss: 0.526/2.155
# [Iteration 122/5600] TRAIN loss: 2.289
# [Iteration 132/5600] TRAIN loss: 2.239
# [Iteration 142/5600] TRAIN loss: 2.215
# [Iteration 152/5600] TRAIN loss: 2.221
# [Iteration 162/5600] TRAIN loss: 2.144
# [Epoch 3/100] TRAIN acc/loss: 0.222/2.144
# [Epoch 3/100] VAL   acc/loss: 0.616/1.862
# [Iteration 178/5600] TRAIN loss: 2.098
# [Iteration 188/5600] TRAIN loss: 2.004
# [Iteration 198/5600] TRAIN loss: 2.025
# [Iteration 208/5600] TRAIN loss: 1.932
# [Iteration 218/5600] TRAIN loss: 1.921
# [Epoch 4/100] TRAIN acc/loss: 0.377/1.921
# [Epoch 4/100] VAL   acc/loss: 0.665/1.677
# [Iteration 234/5600] TRAIN loss: 1.741
# [Iteration 244/5600] TRAIN loss: 1.949
# [Iteration 254/5600] TRAIN loss: 1.852
# [Iteration 264/5600] TRAIN loss: 1.728
# [Iteration 274/5600] TRAIN loss: 1.723
# [Epoch 5/100] TRAIN acc/loss: 0.015/1.723
# [Epoch 5/100] VAL   acc/loss: 0.725/1.519
# [Iteration 290/5600] TRAIN loss: 1.781
# [Iteration 300/5600] TRAIN loss: 1.739
# [Iteration 310/5600] TRAIN loss: 1.618
# [Iteration 320/5600] TRAIN loss: 1.594
# [Iteration 330/5600] TRAIN loss: 1.566
# [Epoch 6/100] TRAIN acc/loss: 0.712/1.566
# [Epoch 6/100] VAL   acc/loss: 0.730/1.441
# [Iteration 346/5600] TRAIN loss: 1.490
# [Iteration 356/5600] TRAIN loss: 1.674
# [Iteration 366/5600] TRAIN loss: 1.500
# [Iteration 376/5600] TRAIN loss: 1.495
# [Iteration 386/5600] TRAIN loss: 1.430
# [Epoch 7/100] TRAIN acc/loss: 0.618/1.430
# [Epoch 7/100] VAL   acc/loss: 0.765/1.292
# [Iteration 402/5600] TRAIN loss: 1.518
# [Iteration 412/5600] TRAIN loss: 1.422
# [Iteration 422/5600] TRAIN loss: 1.345
# [Iteration 432/5600] TRAIN loss: 1.303
# [Iteration 442/5600] TRAIN loss: 1.242
# [Epoch 8/100] TRAIN acc/loss: 0.442/1.242
# [Epoch 8/100] VAL   acc/loss: 0.784/1.183
# [Iteration 458/5600] TRAIN loss: 1.324
# [Iteration 468/5600] TRAIN loss: 1.324
# [Iteration 478/5600] TRAIN loss: 1.358
# [Iteration 488/5600] TRAIN loss: 1.204
# [Iteration 498/5600] TRAIN loss: 1.195
# [Epoch 9/100] TRAIN acc/loss: 0.462/1.195
# [Epoch 9/100] VAL   acc/loss: 0.786/1.149
# [Iteration 514/5600] TRAIN loss: 1.288
# [Iteration 524/5600] TRAIN loss: 1.233
# [Iteration 534/5600] TRAIN loss: 1.199
# [Iteration 544/5600] TRAIN loss: 1.134
# [Iteration 554/5600] TRAIN loss: 1.131
# [Epoch 10/100] TRAIN acc/loss: 0.908/1.131
# [Epoch 10/100] VAL   acc/loss: 0.809/1.083
# [Iteration 570/5600] TRAIN loss: 1.066
# [Iteration 580/5600] TRAIN loss: 1.240
# [Iteration 590/5600] TRAIN loss: 1.075
# [Iteration 600/5600] TRAIN loss: 1.061
# [Iteration 610/5600] TRAIN loss: 1.008
# [Epoch 11/100] TRAIN acc/loss: 0.250/1.008
# [Epoch 11/100] VAL   acc/loss: 0.817/1.025
# [Iteration 626/5600] TRAIN loss: 0.921
# [Iteration 636/5600] TRAIN loss: 1.114
# [Iteration 646/5600] TRAIN loss: 1.164
# [Iteration 656/5600] TRAIN loss: 1.116
# [Iteration 666/5600] TRAIN loss: 1.017
# [Epoch 12/100] TRAIN acc/loss: 0.383/1.017
# [Epoch 12/100] VAL   acc/loss: 0.855/0.885
# [Iteration 682/5600] TRAIN loss: 1.095
# [Iteration 692/5600] TRAIN loss: 1.111
# [Iteration 702/5600] TRAIN loss: 1.046
# [Iteration 712/5600] TRAIN loss: 0.919
# [Iteration 722/5600] TRAIN loss: 0.926
# [Epoch 13/100] TRAIN acc/loss: 0.353/0.926
# [Epoch 13/100] VAL   acc/loss: 0.850/0.876
# [Iteration 738/5600] TRAIN loss: 0.920
# [Iteration 748/5600] TRAIN loss: 0.871
# [Iteration 758/5600] TRAIN loss: 0.811
# [Iteration 768/5600] TRAIN loss: 0.861
# [Iteration 778/5600] TRAIN loss: 0.872
# [Epoch 14/100] TRAIN acc/loss: 0.693/0.872
# [Epoch 14/100] VAL   acc/loss: 0.833/0.877
# [Iteration 794/5600] TRAIN loss: 0.778
# [Iteration 804/5600] TRAIN loss: 0.794
# [Iteration 814/5600] TRAIN loss: 0.769
# [Iteration 824/5600] TRAIN loss: 0.757
# [Iteration 834/5600] TRAIN loss: 0.805
# [Epoch 15/100] TRAIN acc/loss: 0.313/0.805
# [Epoch 15/100] VAL   acc/loss: 0.860/0.753
# [Iteration 850/5600] TRAIN loss: 0.812
# [Iteration 860/5600] TRAIN loss: 0.727
# [Iteration 870/5600] TRAIN loss: 0.682
# [Iteration 880/5600] TRAIN loss: 0.661
# [Iteration 890/5600] TRAIN loss: 0.765
# [Epoch 16/100] TRAIN acc/loss: 0.710/0.765
# [Epoch 16/100] VAL   acc/loss: 0.854/0.775
# [Iteration 906/5600] TRAIN loss: 0.645
# [Iteration 916/5600] TRAIN loss: 0.722
# [Iteration 926/5600] TRAIN loss: 0.695
# [Iteration 936/5600] TRAIN loss: 0.662
# [Iteration 946/5600] TRAIN loss: 0.665
# [Epoch 17/100] TRAIN acc/loss: 0.217/0.665
# [Epoch 17/100] VAL   acc/loss: 0.838/0.780
# [Iteration 962/5600] TRAIN loss: 0.677
# [Iteration 972/5600] TRAIN loss: 0.678
# [Iteration 982/5600] TRAIN loss: 0.609
# [Iteration 992/5600] TRAIN loss: 0.601
# [Iteration 1002/5600] TRAIN loss: 0.625
# [Epoch 18/100] TRAIN acc/loss: 0.784/0.625
# [Epoch 18/100] VAL   acc/loss: 0.807/0.859
# [Iteration 1018/5600] TRAIN loss: 0.574
# [Iteration 1028/5600] TRAIN loss: 0.659
# [Iteration 1038/5600] TRAIN loss: 0.652
# [Iteration 1048/5600] TRAIN loss: 0.572
# [Iteration 1058/5600] TRAIN loss: 0.585
# [Epoch 19/100] TRAIN acc/loss: 0.421/0.585
# [Epoch 19/100] VAL   acc/loss: 0.837/0.759
# [Iteration 1074/5600] TRAIN loss: 0.496
# [Iteration 1084/5600] TRAIN loss: 0.651
# [Iteration 1094/5600] TRAIN loss: 0.535
# [Iteration 1104/5600] TRAIN loss: 0.562
# [Iteration 1114/5600] TRAIN loss: 0.531
# [Epoch 20/100] TRAIN acc/loss: 0.503/0.531
# [Epoch 20/100] VAL   acc/loss: 0.860/0.689
# [Iteration 1130/5600] TRAIN loss: 0.515
# [Iteration 1140/5600] TRAIN loss: 0.550
# [Iteration 1150/5600] TRAIN loss: 0.526
# [Iteration 1160/5600] TRAIN loss: 0.502
# [Iteration 1170/5600] TRAIN loss: 0.483
# [Epoch 21/100] TRAIN acc/loss: 0.003/0.483
# [Epoch 21/100] VAL   acc/loss: 0.861/0.663
# [Iteration 1186/5600] TRAIN loss: 0.486
# [Iteration 1196/5600] TRAIN loss: 0.583
# [Iteration 1206/5600] TRAIN loss: 0.513
# [Iteration 1216/5600] TRAIN loss: 0.400
# [Iteration 1226/5600] TRAIN loss: 0.491
# [Epoch 22/100] TRAIN acc/loss: 0.576/0.491
# [Epoch 22/100] VAL   acc/loss: 0.852/0.690
# [Iteration 1242/5600] TRAIN loss: 0.481
# [Iteration 1252/5600] TRAIN loss: 0.538
# [Iteration 1262/5600] TRAIN loss: 0.430
# [Iteration 1272/5600] TRAIN loss: 0.451
# [Iteration 1282/5600] TRAIN loss: 0.391
# [Epoch 23/100] TRAIN acc/loss: 0.202/0.391
# [Epoch 23/100] VAL   acc/loss: 0.858/0.645
# [Iteration 1298/5600] TRAIN loss: 0.378
# [Iteration 1308/5600] TRAIN loss: 0.520
# [Iteration 1318/5600] TRAIN loss: 0.409
# [Iteration 1328/5600] TRAIN loss: 0.381
# [Iteration 1338/5600] TRAIN loss: 0.374
# [Epoch 24/100] TRAIN acc/loss: 0.975/0.374
# [Epoch 24/100] VAL   acc/loss: 0.864/0.637
# [Iteration 1354/5600] TRAIN loss: 0.385
# [Iteration 1364/5600] TRAIN loss: 0.410
# [Iteration 1374/5600] TRAIN loss: 0.314
# [Iteration 1384/5600] TRAIN loss: 0.354
# [Iteration 1394/5600] TRAIN loss: 0.315
# [Epoch 25/100] TRAIN acc/loss: 0.222/0.315
# [Epoch 25/100] VAL   acc/loss: 0.863/0.614
# [Iteration 1410/5600] TRAIN loss: 0.359
# [Iteration 1420/5600] TRAIN loss: 0.312
# [Iteration 1430/5600] TRAIN loss: 0.337
# [Iteration 1440/5600] TRAIN loss: 0.328
# [Iteration 1450/5600] TRAIN loss: 0.339
# [Epoch 26/100] TRAIN acc/loss: 0.648/0.339
# [Epoch 26/100] VAL   acc/loss: 0.859/0.630
# [Iteration 1466/5600] TRAIN loss: 0.417
# [Iteration 1476/5600] TRAIN loss: 0.449
# [Iteration 1486/5600] TRAIN loss: 0.319
# [Iteration 1496/5600] TRAIN loss: 0.330
# [Iteration 1506/5600] TRAIN loss: 0.364
# [Epoch 27/100] TRAIN acc/loss: 0.839/0.364
# [Epoch 27/100] VAL   acc/loss: 0.864/0.613
# [Iteration 1522/5600] TRAIN loss: 0.304
# [Iteration 1532/5600] TRAIN loss: 0.370
# [Iteration 1542/5600] TRAIN loss: 0.382
# [Iteration 1552/5600] TRAIN loss: 0.346
# [Iteration 1562/5600] TRAIN loss: 0.409
# [Epoch 28/100] TRAIN acc/loss: 0.819/0.409
# [Epoch 28/100] VAL   acc/loss: 0.802/0.930
# [Iteration 1578/5600] TRAIN loss: 0.330
# [Iteration 1588/5600] TRAIN loss: 0.372
# [Iteration 1598/5600] TRAIN loss: 0.351
# [Iteration 1608/5600] TRAIN loss: 0.323
# [Iteration 1618/5600] TRAIN loss: 0.321
# [Epoch 29/100] TRAIN acc/loss: 0.658/0.321
# [Epoch 29/100] VAL   acc/loss: 0.859/0.649
# [Iteration 1634/5600] TRAIN loss: 0.328
# [Iteration 1644/5600] TRAIN loss: 0.295
# [Iteration 1654/5600] TRAIN loss: 0.290
# [Iteration 1664/5600] TRAIN loss: 0.339
# [Iteration 1674/5600] TRAIN loss: 0.284
# [Epoch 30/100] TRAIN acc/loss: 0.228/0.284
# [Epoch 30/100] VAL   acc/loss: 0.882/0.537
# [Iteration 1690/5600] TRAIN loss: 0.277
# [Iteration 1700/5600] TRAIN loss: 0.274
# [Iteration 1710/5600] TRAIN loss: 0.284
# [Iteration 1720/5600] TRAIN loss: 0.299
# [Iteration 1730/5600] TRAIN loss: 0.277
# [Epoch 31/100] TRAIN acc/loss: 0.967/0.277
# [Epoch 31/100] VAL   acc/loss: 0.868/0.605
# [Iteration 1746/5600] TRAIN loss: 0.245
# [Iteration 1756/5600] TRAIN loss: 0.220
# [Iteration 1766/5600] TRAIN loss: 0.226
# [Iteration 1776/5600] TRAIN loss: 0.251
# [Iteration 1786/5600] TRAIN loss: 0.214
# [Epoch 32/100] TRAIN acc/loss: 0.303/0.214
# [Epoch 32/100] VAL   acc/loss: 0.859/0.638
# [Iteration 1802/5600] TRAIN loss: 0.238
# [Iteration 1812/5600] TRAIN loss: 0.254
# [Iteration 1822/5600] TRAIN loss: 0.223
# [Iteration 1832/5600] TRAIN loss: 0.209
# [Iteration 1842/5600] TRAIN loss: 0.202
# [Epoch 33/100] TRAIN acc/loss: 0.313/0.202
# [Epoch 33/100] VAL   acc/loss: 0.862/0.614
# [Iteration 1858/5600] TRAIN loss: 0.271
# [Iteration 1868/5600] TRAIN loss: 0.235
# [Iteration 1878/5600] TRAIN loss: 0.237
# [Iteration 1888/5600] TRAIN loss: 0.191
# [Iteration 1898/5600] TRAIN loss: 0.168
# [Epoch 34/100] TRAIN acc/loss: 0.379/0.168
# [Epoch 34/100] VAL   acc/loss: 0.876/0.538
# [Iteration 1914/5600] TRAIN loss: 0.253
# [Iteration 1924/5600] TRAIN loss: 0.189
# [Iteration 1934/5600] TRAIN loss: 0.175
# [Iteration 1944/5600] TRAIN loss: 0.216
# [Iteration 1954/5600] TRAIN loss: 0.196
# [Epoch 35/100] TRAIN acc/loss: 0.619/0.196
# [Epoch 35/100] VAL   acc/loss: 0.878/0.541
# [Iteration 1970/5600] TRAIN loss: 0.188
# [Iteration 1980/5600] TRAIN loss: 0.237
# [Iteration 1990/5600] TRAIN loss: 0.206
# [Iteration 2000/5600] TRAIN loss: 0.181
# [Iteration 2010/5600] TRAIN loss: 0.213
# [Epoch 36/100] TRAIN acc/loss: 0.810/0.213
# [Epoch 36/100] VAL   acc/loss: 0.876/0.550
# [Iteration 2026/5600] TRAIN loss: 0.171
# [Iteration 2036/5600] TRAIN loss: 0.190
# [Iteration 2046/5600] TRAIN loss: 0.193
# [Iteration 2056/5600] TRAIN loss: 0.189
# [Iteration 2066/5600] TRAIN loss: 0.167
# [Epoch 37/100] TRAIN acc/loss: 0.678/0.167
# [Epoch 37/100] VAL   acc/loss: 0.861/0.599
# [Iteration 2082/5600] TRAIN loss: 0.216
# [Iteration 2092/5600] TRAIN loss: 0.209
# [Iteration 2102/5600] TRAIN loss: 0.245
# [Iteration 2112/5600] TRAIN loss: 0.193
# [Iteration 2122/5600] TRAIN loss: 0.292
# [Epoch 38/100] TRAIN acc/loss: 0.865/0.292
# [Epoch 38/100] VAL   acc/loss: 0.857/0.616
# [Iteration 2138/5600] TRAIN loss: 0.193
# [Iteration 2148/5600] TRAIN loss: 0.191
# [Iteration 2158/5600] TRAIN loss: 0.195
# [Iteration 2168/5600] TRAIN loss: 0.192
# [Iteration 2178/5600] TRAIN loss: 0.228
# [Epoch 39/100] TRAIN acc/loss: 0.390/0.228
# [Epoch 39/100] VAL   acc/loss: 0.869/0.568
# [Iteration 2194/5600] TRAIN loss: 0.191
# [Iteration 2204/5600] TRAIN loss: 0.254
# [Iteration 2214/5600] TRAIN loss: 0.178
# [Iteration 2224/5600] TRAIN loss: 0.172
# [Iteration 2234/5600] TRAIN loss: 0.172
# [Epoch 40/100] TRAIN acc/loss: 0.713/0.172
# [Epoch 40/100] VAL   acc/loss: 0.868/0.578
# [Iteration 2250/5600] TRAIN loss: 0.177
# [Iteration 2260/5600] TRAIN loss: 0.222
# [Iteration 2270/5600] TRAIN loss: 0.221
# [Iteration 2280/5600] TRAIN loss: 0.185
# [Iteration 2290/5600] TRAIN loss: 0.156
# [Epoch 41/100] TRAIN acc/loss: 0.226/0.156
# [Epoch 41/100] VAL   acc/loss: 0.846/0.681
# [Iteration 2306/5600] TRAIN loss: 0.189
# [Iteration 2316/5600] TRAIN loss: 0.192
# [Iteration 2326/5600] TRAIN loss: 0.228
# [Iteration 2336/5600] TRAIN loss: 0.163
# [Iteration 2346/5600] TRAIN loss: 0.139
# [Epoch 42/100] TRAIN acc/loss: 0.422/0.139
# [Epoch 42/100] VAL   acc/loss: 0.862/0.603
# [Iteration 2362/5600] TRAIN loss: 0.128
# [Iteration 2372/5600] TRAIN loss: 0.209
# [Iteration 2382/5600] TRAIN loss: 0.130
# [Iteration 2392/5600] TRAIN loss: 0.143
# [Iteration 2402/5600] TRAIN loss: 0.134
# [Epoch 43/100] TRAIN acc/loss: 0.910/0.134
# [Epoch 43/100] VAL   acc/loss: 0.877/0.545
# [Iteration 2418/5600] TRAIN loss: 0.139
# [Iteration 2428/5600] TRAIN loss: 0.122
# [Iteration 2438/5600] TRAIN loss: 0.110
# [Iteration 2448/5600] TRAIN loss: 0.157
# [Iteration 2458/5600] TRAIN loss: 0.117
# [Epoch 44/100] TRAIN acc/loss: 0.794/0.117
# [Epoch 44/100] VAL   acc/loss: 0.870/0.551
# [Iteration 2474/5600] TRAIN loss: 0.162
# [Iteration 2484/5600] TRAIN loss: 0.147
# [Iteration 2494/5600] TRAIN loss: 0.099
# [Iteration 2504/5600] TRAIN loss: 0.095
# [Iteration 2514/5600] TRAIN loss: 0.121
# [Epoch 45/100] TRAIN acc/loss: 0.910/0.121
# [Epoch 45/100] VAL   acc/loss: 0.877/0.536
# [Iteration 2530/5600] TRAIN loss: 0.098
# [Iteration 2540/5600] TRAIN loss: 0.146
# [Iteration 2550/5600] TRAIN loss: 0.138
# [Iteration 2560/5600] TRAIN loss: 0.103
# [Iteration 2570/5600] TRAIN loss: 0.103
# [Epoch 46/100] TRAIN acc/loss: 0.747/0.103
# [Epoch 46/100] VAL   acc/loss: 0.867/0.566
# [Iteration 2586/5600] TRAIN loss: 0.136
# [Iteration 2596/5600] TRAIN loss: 0.143
# [Iteration 2606/5600] TRAIN loss: 0.126
# [Iteration 2616/5600] TRAIN loss: 0.170
# [Iteration 2626/5600] TRAIN loss: 0.102
# [Epoch 47/100] TRAIN acc/loss: 0.670/0.102
# [Epoch 47/100] VAL   acc/loss: 0.877/0.526
# [Iteration 2642/5600] TRAIN loss: 0.172
# [Iteration 2652/5600] TRAIN loss: 0.162
# [Iteration 2662/5600] TRAIN loss: 0.127
# [Iteration 2672/5600] TRAIN loss: 0.134
# [Iteration 2682/5600] TRAIN loss: 0.097
# [Epoch 48/100] TRAIN acc/loss: 0.928/0.097
# [Epoch 48/100] VAL   acc/loss: 0.881/0.538
# [Iteration 2698/5600] TRAIN loss: 0.108
# [Iteration 2708/5600] TRAIN loss: 0.075
# [Iteration 2718/5600] TRAIN loss: 0.152
# [Iteration 2728/5600] TRAIN loss: 0.102
# [Iteration 2738/5600] TRAIN loss: 0.141
# [Epoch 49/100] TRAIN acc/loss: 0.968/0.141
# [Epoch 49/100] VAL   acc/loss: 0.865/0.577
# [Iteration 2754/5600] TRAIN loss: 0.171
# [Iteration 2764/5600] TRAIN loss: 0.102
# [Iteration 2774/5600] TRAIN loss: 0.152
# [Iteration 2784/5600] TRAIN loss: 0.096
# [Iteration 2794/5600] TRAIN loss: 0.105
# [Epoch 50/100] TRAIN acc/loss: 0.768/0.105
# [Epoch 50/100] VAL   acc/loss: 0.862/0.595
# [Iteration 2810/5600] TRAIN loss: 0.109
# [Iteration 2820/5600] TRAIN loss: 0.110
# [Iteration 2830/5600] TRAIN loss: 0.103
# [Iteration 2840/5600] TRAIN loss: 0.094
# [Iteration 2850/5600] TRAIN loss: 0.112
# [Epoch 51/100] TRAIN acc/loss: 0.555/0.112
# [Epoch 51/100] VAL   acc/loss: 0.873/0.555
# [Iteration 2866/5600] TRAIN loss: 0.149
# [Iteration 2876/5600] TRAIN loss: 0.110
# [Iteration 2886/5600] TRAIN loss: 0.120
# [Iteration 2896/5600] TRAIN loss: 0.077
# [Iteration 2906/5600] TRAIN loss: 0.123
# [Epoch 52/100] TRAIN acc/loss: 0.719/0.123
# [Epoch 52/100] VAL   acc/loss: 0.847/0.693
# [Iteration 2922/5600] TRAIN loss: 0.075
# [Iteration 2932/5600] TRAIN loss: 0.092
# [Iteration 2942/5600] TRAIN loss: 0.075
# [Iteration 2952/5600] TRAIN loss: 0.099
# [Iteration 2962/5600] TRAIN loss: 0.092
# [Epoch 53/100] TRAIN acc/loss: 0.884/0.092
# [Epoch 53/100] VAL   acc/loss: 0.866/0.585
# [Iteration 2978/5600] TRAIN loss: 0.080
# [Iteration 2988/5600] TRAIN loss: 0.074
# [Iteration 2998/5600] TRAIN loss: 0.076
# [Iteration 3008/5600] TRAIN loss: 0.093
# [Iteration 3018/5600] TRAIN loss: 0.076
# [Epoch 54/100] TRAIN acc/loss: 0.903/0.076
# [Epoch 54/100] VAL   acc/loss: 0.877/0.542
# [Iteration 3034/5600] TRAIN loss: 0.063
# [Iteration 3044/5600] TRAIN loss: 0.066
# [Iteration 3054/5600] TRAIN loss: 0.090
# [Iteration 3064/5600] TRAIN loss: 0.071
# [Iteration 3074/5600] TRAIN loss: 0.088
# [Epoch 55/100] TRAIN acc/loss: 0.974/0.088
# [Epoch 55/100] VAL   acc/loss: 0.885/0.516
# [Iteration 3090/5600] TRAIN loss: 0.075
# [Iteration 3100/5600] TRAIN loss: 0.074
# [Iteration 3110/5600] TRAIN loss: 0.047
# [Iteration 3120/5600] TRAIN loss: 0.064
# [Iteration 3130/5600] TRAIN loss: 0.058
# [Epoch 56/100] TRAIN acc/loss: 0.963/0.058
# [Epoch 56/100] VAL   acc/loss: 0.877/0.557
# [Iteration 3146/5600] TRAIN loss: 0.057
# [Iteration 3156/5600] TRAIN loss: 0.062
# [Iteration 3166/5600] TRAIN loss: 0.067
# [Iteration 3176/5600] TRAIN loss: 0.048
# [Iteration 3186/5600] TRAIN loss: 0.065
# [Epoch 57/100] TRAIN acc/loss: 0.577/0.065
# [Epoch 57/100] VAL   acc/loss: 0.881/0.538
# [Iteration 3202/5600] TRAIN loss: 0.089
# [Iteration 3212/5600] TRAIN loss: 0.108
# [Iteration 3222/5600] TRAIN loss: 0.073
# [Iteration 3232/5600] TRAIN loss: 0.080
# [Iteration 3242/5600] TRAIN loss: 0.075
# [Epoch 58/100] TRAIN acc/loss: 0.946/0.075
# [Epoch 58/100] VAL   acc/loss: 0.881/0.538
# [Iteration 3258/5600] TRAIN loss: 0.085
# [Iteration 3268/5600] TRAIN loss: 0.053
# [Iteration 3278/5600] TRAIN loss: 0.072
# [Iteration 3288/5600] TRAIN loss: 0.187
# [Iteration 3298/5600] TRAIN loss: 0.073
# [Epoch 59/100] TRAIN acc/loss: 0.939/0.073
# [Epoch 59/100] VAL   acc/loss: 0.869/0.585
# [Iteration 3314/5600] TRAIN loss: 0.081
# [Iteration 3324/5600] TRAIN loss: 0.123
# [Iteration 3334/5600] TRAIN loss: 0.084
# [Iteration 3344/5600] TRAIN loss: 0.064
# [Iteration 3354/5600] TRAIN loss: 0.079
# [Epoch 60/100] TRAIN acc/loss: 0.969/0.079
# [Epoch 60/100] VAL   acc/loss: 0.874/0.556
# [Iteration 3370/5600] TRAIN loss: 0.056
# [Iteration 3380/5600] TRAIN loss: 0.075
# [Iteration 3390/5600] TRAIN loss: 0.049
# [Iteration 3400/5600] TRAIN loss: 0.050
# [Iteration 3410/5600] TRAIN loss: 0.068
# [Epoch 61/100] TRAIN acc/loss: 0.759/0.068
# [Epoch 61/100] VAL   acc/loss: 0.882/0.540
# [Iteration 3426/5600] TRAIN loss: 0.062
# [Iteration 3436/5600] TRAIN loss: 0.045
# [Iteration 3446/5600] TRAIN loss: 0.064
# [Iteration 3456/5600] TRAIN loss: 0.105
# [Iteration 3466/5600] TRAIN loss: 0.048
# [Epoch 62/100] TRAIN acc/loss: 0.998/0.048
# [Epoch 62/100] VAL   acc/loss: 0.877/0.555
# [Iteration 3482/5600] TRAIN loss: 0.048
# [Iteration 3492/5600] TRAIN loss: 0.045
# [Iteration 3502/5600] TRAIN loss: 0.057
# [Iteration 3512/5600] TRAIN loss: 0.081
# [Iteration 3522/5600] TRAIN loss: 0.053
# [Epoch 63/100] TRAIN acc/loss: 0.395/0.053
# [Epoch 63/100] VAL   acc/loss: 0.877/0.560
# [Iteration 3538/5600] TRAIN loss: 0.060
# [Iteration 3548/5600] TRAIN loss: 0.058
# [Iteration 3558/5600] TRAIN loss: 0.063
# [Iteration 3568/5600] TRAIN loss: 0.062
# [Iteration 3578/5600] TRAIN loss: 0.058
# [Epoch 64/100] TRAIN acc/loss: 0.650/0.058
# [Epoch 64/100] VAL   acc/loss: 0.872/0.574
# [Iteration 3594/5600] TRAIN loss: 0.053
# [Iteration 3604/5600] TRAIN loss: 0.066
# [Iteration 3614/5600] TRAIN loss: 0.045
# [Iteration 3624/5600] TRAIN loss: 0.071
# [Iteration 3634/5600] TRAIN loss: 0.045
# [Epoch 65/100] TRAIN acc/loss: 0.464/0.045
# [Epoch 65/100] VAL   acc/loss: 0.856/0.639
# [Iteration 3650/5600] TRAIN loss: 0.077
# [Iteration 3660/5600] TRAIN loss: 0.076
# [Iteration 3670/5600] TRAIN loss: 0.060
# [Iteration 3680/5600] TRAIN loss: 0.099
# [Iteration 3690/5600] TRAIN loss: 0.070
# [Epoch 66/100] TRAIN acc/loss: 0.781/0.070
# [Epoch 66/100] VAL   acc/loss: 0.848/0.661
# [Iteration 3706/5600] TRAIN loss: 0.098
# [Iteration 3716/5600] TRAIN loss: 0.071
# [Iteration 3726/5600] TRAIN loss: 0.067
# [Iteration 3736/5600] TRAIN loss: 0.050
# [Iteration 3746/5600] TRAIN loss: 0.051
# [Epoch 67/100] TRAIN acc/loss: 0.555/0.051
# [Epoch 67/100] VAL   acc/loss: 0.866/0.596
# [Iteration 3762/5600] TRAIN loss: 0.128
# [Iteration 3772/5600] TRAIN loss: 0.187
# [Iteration 3782/5600] TRAIN loss: 0.092
# [Iteration 3792/5600] TRAIN loss: 0.093
# [Iteration 3802/5600] TRAIN loss: 0.091
# [Epoch 68/100] TRAIN acc/loss: 0.860/0.091
# [Epoch 68/100] VAL   acc/loss: 0.860/0.609
# [Iteration 3818/5600] TRAIN loss: 0.069
# [Iteration 3828/5600] TRAIN loss: 0.109
# [Iteration 3838/5600] TRAIN loss: 0.083
# [Iteration 3848/5600] TRAIN loss: 0.109
# [Iteration 3858/5600] TRAIN loss: 0.089
# [Epoch 69/100] TRAIN acc/loss: 0.334/0.089
# [Epoch 69/100] VAL   acc/loss: 0.841/0.734
# [Iteration 3874/5600] TRAIN loss: 0.075
# [Iteration 3884/5600] TRAIN loss: 0.107
# [Iteration 3894/5600] TRAIN loss: 0.121
# [Iteration 3904/5600] TRAIN loss: 0.117
# [Iteration 3914/5600] TRAIN loss: 0.069
# [Epoch 70/100] TRAIN acc/loss: 0.370/0.069
# [Epoch 70/100] VAL   acc/loss: 0.852/0.682
# [Iteration 3930/5600] TRAIN loss: 0.058
# [Iteration 3940/5600] TRAIN loss: 0.064
# [Iteration 3950/5600] TRAIN loss: 0.112
# [Iteration 3960/5600] TRAIN loss: 0.058
# [Iteration 3970/5600] TRAIN loss: 0.085
# [Epoch 71/100] TRAIN acc/loss: 0.608/0.085
# [Epoch 71/100] VAL   acc/loss: 0.857/0.656
# [Iteration 3986/5600] TRAIN loss: 0.083
# [Iteration 3996/5600] TRAIN loss: 0.104
# [Iteration 4006/5600] TRAIN loss: 0.131
# [Iteration 4016/5600] TRAIN loss: 0.075
# [Iteration 4026/5600] TRAIN loss: 0.089
# [Epoch 72/100] TRAIN acc/loss: 0.568/0.089
# [Epoch 72/100] VAL   acc/loss: 0.869/0.569
# [Iteration 4042/5600] TRAIN loss: 0.071
# [Iteration 4052/5600] TRAIN loss: 0.102
# [Iteration 4062/5600] TRAIN loss: 0.070
# [Iteration 4072/5600] TRAIN loss: 0.090
# [Iteration 4082/5600] TRAIN loss: 0.057
# [Epoch 73/100] TRAIN acc/loss: 0.958/0.057
# [Epoch 73/100] VAL   acc/loss: 0.856/0.663
# [Iteration 4098/5600] TRAIN loss: 0.042
# [Iteration 4108/5600] TRAIN loss: 0.054
# [Iteration 4118/5600] TRAIN loss: 0.039
# [Iteration 4128/5600] TRAIN loss: 0.053
# [Iteration 4138/5600] TRAIN loss: 0.045
# [Epoch 74/100] TRAIN acc/loss: 0.756/0.045
# [Epoch 74/100] VAL   acc/loss: 0.867/0.595
# [Iteration 4154/5600] TRAIN loss: 0.047
# [Iteration 4164/5600] TRAIN loss: 0.085
# [Iteration 4174/5600] TRAIN loss: 0.070
# [Iteration 4184/5600] TRAIN loss: 0.050
# [Iteration 4194/5600] TRAIN loss: 0.045
# [Epoch 75/100] TRAIN acc/loss: 0.946/0.045
# [Epoch 75/100] VAL   acc/loss: 0.862/0.617
# [Iteration 4210/5600] TRAIN loss: 0.036
# [Iteration 4220/5600] TRAIN loss: 0.124
# [Iteration 4230/5600] TRAIN loss: 0.039
# [Iteration 4240/5600] TRAIN loss: 0.043
# [Iteration 4250/5600] TRAIN loss: 0.052
# [Epoch 76/100] TRAIN acc/loss: 0.752/0.052
# [Epoch 76/100] VAL   acc/loss: 0.863/0.632
# [Iteration 4266/5600] TRAIN loss: 0.067
# [Iteration 4276/5600] TRAIN loss: 0.047
# [Iteration 4286/5600] TRAIN loss: 0.045
# [Iteration 4296/5600] TRAIN loss: 0.051
# [Iteration 4306/5600] TRAIN loss: 0.068
# [Epoch 77/100] TRAIN acc/loss: 0.516/0.068
# [Epoch 77/100] VAL   acc/loss: 0.864/0.658
# [Iteration 4322/5600] TRAIN loss: 0.094
# [Iteration 4332/5600] TRAIN loss: 0.059
# [Iteration 4342/5600] TRAIN loss: 0.092
# [Iteration 4352/5600] TRAIN loss: 0.061
# [Iteration 4362/5600] TRAIN loss: 0.061
# [Epoch 78/100] TRAIN acc/loss: 0.983/0.061
# [Epoch 78/100] VAL   acc/loss: 0.861/0.622
# [Iteration 4378/5600] TRAIN loss: 0.040
# [Iteration 4388/5600] TRAIN loss: 0.054
# [Iteration 4398/5600] TRAIN loss: 0.044
# [Iteration 4408/5600] TRAIN loss: 0.038
# [Iteration 4418/5600] TRAIN loss: 0.043
# [Epoch 79/100] TRAIN acc/loss: 0.887/0.043
# [Epoch 79/100] VAL   acc/loss: 0.862/0.633
# [Iteration 4434/5600] TRAIN loss: 0.035
# [Iteration 4444/5600] TRAIN loss: 0.050
# [Iteration 4454/5600] TRAIN loss: 0.052
# [Iteration 4464/5600] TRAIN loss: 0.032
# [Iteration 4474/5600] TRAIN loss: 0.039
# [Epoch 80/100] TRAIN acc/loss: 0.969/0.039
# [Epoch 80/100] VAL   acc/loss: 0.865/0.646
# [Iteration 4490/5600] TRAIN loss: 0.065
# [Iteration 4500/5600] TRAIN loss: 0.055
# [Iteration 4510/5600] TRAIN loss: 0.035
# [Iteration 4520/5600] TRAIN loss: 0.035
# [Iteration 4530/5600] TRAIN loss: 0.036
# [Epoch 81/100] TRAIN acc/loss: 0.524/0.036
# [Epoch 81/100] VAL   acc/loss: 0.873/0.560
# [Iteration 4546/5600] TRAIN loss: 0.044
# [Iteration 4556/5600] TRAIN loss: 0.082
# [Iteration 4566/5600] TRAIN loss: 0.118
# [Iteration 4576/5600] TRAIN loss: 0.203
# [Iteration 4586/5600] TRAIN loss: 0.117
# [Epoch 82/100] TRAIN acc/loss: 0.830/0.117
# [Epoch 82/100] VAL   acc/loss: 0.855/0.696
# [Iteration 4602/5600] TRAIN loss: 0.115
# [Iteration 4612/5600] TRAIN loss: 0.151
# [Iteration 4622/5600] TRAIN loss: 0.057
# [Iteration 4632/5600] TRAIN loss: 0.047
# [Iteration 4642/5600] TRAIN loss: 0.057
# [Epoch 83/100] TRAIN acc/loss: 0.329/0.057
# [Epoch 83/100] VAL   acc/loss: 0.836/0.764
# [Iteration 4658/5600] TRAIN loss: 0.056
# [Iteration 4668/5600] TRAIN loss: 0.084
# [Iteration 4678/5600] TRAIN loss: 0.057
# [Iteration 4688/5600] TRAIN loss: 0.077
# [Iteration 4698/5600] TRAIN loss: 0.094
# [Epoch 84/100] TRAIN acc/loss: 0.837/0.094
# [Epoch 84/100] VAL   acc/loss: 0.820/0.918
# [Iteration 4714/5600] TRAIN loss: 0.036
# [Iteration 4724/5600] TRAIN loss: 0.043
# [Iteration 4734/5600] TRAIN loss: 0.149
# [Iteration 4744/5600] TRAIN loss: 0.099
# [Iteration 4754/5600] TRAIN loss: 0.042
# [Epoch 85/100] TRAIN acc/loss: 0.975/0.042
# [Epoch 85/100] VAL   acc/loss: 0.824/0.883
# Process Process-682:
# Process Process-683:
# Process Process-684:
# Process Process-681:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/prakt/w388/.local/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 36, in _worker_loop
#     r = index_queue.get()
#   File "/usr/prakt/w388/.local/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 36, in _worker_loop
#     r = index_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 343, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/usr/prakt/w388/.local/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 36, in _worker_loop
#     r = index_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/usr/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/prakt/w388/.local/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 42, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/usr/prakt/w388/.local/lib/python3.5/site-packages/numpy/core/_methods.py", line 41, in _all
#     return umr_all(a, axis, dtype, out, keepdims)
#   File "/usr/prakt/w388/.local/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 42, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/usr/prakt/w388/dl4cv_yyd/exercise_3/dl4cv/data_utils.py", line 74, in __getitem__
#     return self.get_item_from_index(key)
#   File "/usr/prakt/w388/dl4cv_yyd/exercise_3/dl4cv/data_utils.py", line 100, in get_item_from_index
#     mask = np.all(target == label['rgb_values'], axis=2)
#   File "/usr/prakt/w388/.local/lib/python3.5/site-packages/numpy/core/fromnumeric.py", line 2050, in all
#     return arr.all(axis=axis, out=out, **kwargs)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-b814c1b0b702> in <module>()
#      25 model = SegmentationNN()
#      26 solver = Solver(optim_args={"lr": 1e-4,"weight_decay": 1e-4},                loss_func=torch.nn.CrossEntropyLoss(size_average=True,ignore_index=-1))
# ---> 27 solver.train(model, train_loader, val_loader, log_nth=10, num_epochs=100)
#
# ~/dl4cv_yyd/exercise_3/dl4cv/solver.py in train(self, model, train_loader, val_loader, num_epochs, log_nth)
#      84                 optim.step()
#      85
# ---> 86                 self.train_loss_history.append(loss.data.cpu().numpy())
#      87                 if log_nth and i % log_nth == 0:
#      88                     last_log_nth_losses = self.train_loss_history[-log_nth:]
#
# ~/.local/lib/python3.5/site-packages/torch/tensor.py in cpu(self)
#      33     def cpu(self):
#      34         """Returns a CPU copy of this tensor if it's not already on the CPU"""
# ---> 35         return self.type(getattr(torch, self.__class__.__name__))
#      36
#      37     def double(self):
#
# ~/.local/lib/python3.5/site-packages/torch/cuda/__init__.py in type(self, *args, **kwargs)
#     368     def type(self, *args, **kwargs):
#     369         with device(self.get_device()):
# --> 370             return super(_CudaBase, self).type(*args, **kwargs)
#     371
#     372     __new__ = _lazy_new
#
# ~/.local/lib/python3.5/site-packages/torch/_utils.py in _type(self, new_type, async)
#      36     if new_type.is_sparse:
#      37         raise RuntimeError("Cannot cast dense tensor to sparse tensor")
# ---> 38     return new_type(self.size()).copy_(self, async)
#      39
#      40
#
# KeyboardInterrupt:

# %% [markdown]
# # Test your Model
#
# Your model should easily yield a pixel accuracy of more than 60%.

# %%
test_data = SegmentationData(image_paths_file='datasets/segmentation_data_test/test.txt')
test_loader = torch.utils.data.DataLoader(test_data,
                                          batch_size=1,
                                          shuffle=False,
                                          num_workers=1)

test_scores = []
#model=overfit_model###############
model.eval()
for inputs, targets in test_loader:
    inputs, targets = Variable(inputs), Variable(targets)
    if model.is_cuda:
        inputs, targets = inputs.cuda(), targets.cuda()
    
    outputs = model.forward(inputs)
    _, preds = torch.max(outputs, 1)
    targets_mask = targets >= 0
    test_scores.append(np.mean((preds == targets)[targets_mask].data.cpu().numpy()))
    
model.train()
np.mean(test_scores)
# Out:
# 0.86718317360390418

# %% [markdown]
# # Visualization

# %%
num_example_imgs = 4
plt.figure(figsize=(15, 5 * num_example_imgs))
for i, (img, target) in enumerate(test_data[:num_example_imgs]):
    inputs = img.unsqueeze(0)
    inputs = Variable(inputs)
    if model.is_cuda:
        inputs = inputs.cuda()
    
    outputs = model.forward(inputs)
    _, preds = torch.max(outputs, 1)
    pred = preds[0].data.cpu()
    
    img, target, pred = img.numpy(), target.numpy(), pred.numpy()
    
    # img
    plt.subplot(num_example_imgs, 3, i * 3 + 1)
    plt.axis('off')
    plt.imshow(img.transpose(1,2,0))
    if i == 0:
        plt.title("Input image")
    
    # target
    plt.subplot(num_example_imgs, 3, i * 3 + 2)
    plt.axis('off')
    plt.imshow(label_img_to_rgb(target))
    if i == 0:
        plt.title("Target image")

    # pred
    plt.subplot(num_example_imgs, 3, i * 3 + 3)
    plt.axis('off')
    plt.imshow(label_img_to_rgb(pred))
    if i == 0:
        plt.title("Prediction image")
    
plt.show()

# %% [markdown]
# ## Visualize Filter Weights
# You can visualize the convolutional filters of the very first layer by running the following cell. The kernels should exhibit clear structures of differently oriented edges, corners and circles.

# %%
from dl4cv.vis_utils import visualize_grid

# first (next) parameter should be convolutional
conv_params = next(model.parameters()).data.cpu().numpy()
grid = visualize_grid(conv_params.transpose(0, 2, 3, 1))
plt.imshow(grid.astype('uint8'))
plt.axis('off')
plt.gcf().set_size_inches(6, 6)
plt.show()

# %% [markdown]
# ## Save the Model
#
# When you are satisfied with your training, save the model for submission.

# %%
model.save("models/segmentation_nn.model")
# Out:
# Saving model... models/segmentation_nn.model

# %% [markdown]
# ## Possible Next Steps
#
# 1. Implement and integrate a task specific metric such as [Intersection over Union (IoU)](http://www.pyimagesearch.com/2016/11/07/intersection-over-union-iou-for-object-detection/)
# 2. Hyperparameter optimization
# 3. Data augmentation ([PyTorch tutorial](http://pytorch.org/tutorials/beginner/data_loading_tutorial.html))

# %% [markdown]
# ## Scoring function
# We will score the model you have just saved based on the classification accuracy on our test dataset. The scoring function should represent the difficulty of obtaining a good test accuracy and should therefore give 0 points for worse results than random guessing, should be linear in a first regime and exponential beyond that. The onset of exponential growth depends on the problem. In that region you get twice as many points for an additional 10% accuracy.
#
# For this problem we specifically use the following scoring function:
#     $$f(x) = \left\{
# 	\begin{array}{ll}
# 		0  & \mbox{if } x \leq 0.1 \\
# 		100x & \mbox{if } 0.1 < x \leq 0.5 \\
#         \left(\frac{50}{\exp(0.5 \ln(2)/0.1)}\right) \exp(x \ln(2)/0.1) & \mbox{if } 0.5 < x \leq 1
# 	\end{array}
# \right.$$
#
# The function can be plotted in the following cell.

# %%
from dl4cv.data_utils import scoring_function

x = np.linspace(0, 1, num=1000)
plt.plot(x, scoring_function(x, lin_exp_boundary=0.5, doubling_rate=0.1))
plt.title('Scoring Function')
plt.xlabel('Test Accuracy')
plt.ylabel('Score')
plt.show()
